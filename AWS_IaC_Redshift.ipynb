# %% [markdown]
# # Creating Redshift Cluster: Infrastructure-as-code

# %%
import pandas as pd
import boto3
import json

# %% [markdown]
# # Load DWH Params from a file

# %%
import configparser
config = configparser.ConfigParser()
config.read_file(open('dwh.cfg'))

KEY                    = config.get('AWS','KEY')
SECRET                 = config.get('AWS','SECRET')

DWH_CLUSTER_TYPE       = config.get("DWH","DWH_CLUSTER_TYPE")
DWH_NUM_NODES          = config.get("DWH","DWH_NUM_NODES")
DWH_NODE_TYPE          = config.get("DWH","DWH_NODE_TYPE")

DWH_CLUSTER_IDENTIFIER = config.get("DWH","DWH_CLUSTER_IDENTIFIER")
DWH_DB                 = config.get("DWH","DWH_DB")
DWH_DB_USER            = config.get("DWH","DWH_DB_USER")
DWH_DB_PASSWORD        = config.get("DWH","DWH_DB_PASSWORD")
DWH_PORT               = config.get("DWH","DWH_PORT")

DWH_IAM_ROLE_NAME      = config.get("DWH", "DWH_IAM_ROLE_NAME")

(DWH_DB_USER, DWH_DB_PASSWORD, DWH_DB)

pd.DataFrame({"Param":
                  ["DWH_CLUSTER_TYPE", "DWH_NUM_NODES", "DWH_NODE_TYPE", "DWH_CLUSTER_IDENTIFIER", "DWH_DB", "DWH_DB_USER","DWH_DB_PASSWORD", "DWH_PORT", "DWH_IAM_ROLE_NAME"],
              "Value":
                  [DWH_CLUSTER_TYPE, DWH_NUM_NODES, DWH_NODE_TYPE, DWH_CLUSTER_IDENTIFIER, DWH_DB, DWH_DB_USER, DWH_PORT,DWH_DB_PASSWORD, DWH_IAM_ROLE_NAME]
             })

# %% [markdown]
# ## Create clients for EC2, S3, IAM, and Redshift

# %%
import boto3

ec2 = boto3.resource('ec2',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                    )

s3 = boto3.resource('s3',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                   )

iam = boto3.client('iam',aws_access_key_id=KEY,
                     aws_secret_access_key=SECRET,
                     region_name='us-west-2'
                  )

redshift = boto3.client('redshift',
                       region_name="us-west-2",
                       aws_access_key_id=KEY,
                       aws_secret_access_key=SECRET
                       )

# %% [markdown]
# ### Check out the sample data sources on S3

# %%
# !pip install s3fs

# %%
import boto3
s3 = boto3.resource('s3',
                    region_name="us-west-2",
                    aws_access_key_id=KEY,
                    aws_secret_access_key=SECRET
                   )
sampleDbBucket =  s3.Bucket("udacity-dend")

# %%
obj_list = list(sampleDbBucket.objects.filter(Prefix='song_data/A/B/C/'))
obj = obj_list[0]
obj

# %%
import pandas as pd
df_song_data = pd.read_json('s3://udacity-dend/song_data/A/B/C/TRABCAS128F14A25E2.json',  lines=True)

# %%
obj_list = list(sampleDbBucket.objects.filter(Prefix='log_data'))
obj = obj_list[1]
obj #s3.ObjectSummary(bucket_name='udacity-dend', key='log_data/2018/11/2018-11-01-events.json')
df_log_data = pd.read_json('

# %%
s3://udacity-dend/log_data/2018/11/2018-11-01-events.json',  lines=True)

# %%
df_log_data.columns
# Out:
# Index(['artist', 'auth', 'firstName', 'gender', 'itemInSession', 'lastName',
#        'length', 'level', 'location', 'method', 'page', 'registration',
#        'sessionId', 'song', 'status', 'ts', 'userAgent', 'userId'],
#       dtype='object')

# %% [markdown]
# ## STEP 1: IAM ROLE
# - Create an IAM Role that makes Redshift able to access S3 bucket (ReadOnly)

# %%
# Create the IAM role
try:
    print("1.1 Creating a new IAM Role") 
    dwhRole = iam.create_role(
        Path='/',
        RoleName=DWH_IAM_ROLE_NAME,
        Description = "Allows Redshift clusters to call AWS services on your behalf.",
        AssumeRolePolicyDocument=json.dumps(
            {'Statement': [{'Action': 'sts:AssumeRole',
               'Effect': 'Allow',
               'Principal': {'Service': 'redshift.amazonaws.com'}}],
             'Version': '2012-10-17'})
    )    
except Exception as e:
    print(e)

# %%
# Attach Policy
print('1.2 Attaching Policy')
iam.attach_role_policy(RoleName=DWH_IAM_ROLE_NAME,
                       PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess"
                      )['ResponseMetadata']['HTTPStatusCode']

# %%
# Get and print the IAM role ARN
print('1.3 Get the IAM role ARN')
roleArn = iam.get_role(RoleName=DWH_IAM_ROLE_NAME)['Role']['Arn']

print(roleArn)

# %% [markdown]
# ## STEP 2:  Redshift Cluster
#
# - Create a RedShift Cluster
# - For complete arguments to `create_cluster`, see [docs](https://boto3.amazonaws.com/v1/documentation/api/latest/reference/services/redshift.html#Redshift.Client.create_cluster)

# %%
try:
    response = redshift.create_cluster(        
        #HW
        ClusterType=DWH_CLUSTER_TYPE,
        NodeType=DWH_NODE_TYPE,
        NumberOfNodes=int(DWH_NUM_NODES),

        #Identifiers & Credentials
        DBName=DWH_DB,
        ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,
        MasterUsername=DWH_DB_USER,
        MasterUserPassword=DWH_DB_PASSWORD,
        
        #Roles (for s3 access)
        IamRoles=[roleArn]  
    )
except Exception as e:
    print(e)

# %% [markdown]
# ## 2.1 *Describe* the cluster to see its status
# - run this block several times until the cluster status becomes `Available`

# %%
def prettyRedshiftProps(props):
    pd.set_option('display.max_colwidth', -1)
    keysToShow = ["ClusterIdentifier", "NodeType", "ClusterStatus", "MasterUsername", "DBName", "Endpoint", "NumberOfNodes", 'VpcId']
    x = [(k, v) for k,v in props.items() if k in keysToShow]
    return pd.DataFrame(data=x, columns=["Key", "Value"])

myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)

# %% [markdown]
# <h2> 2.2 Take note of the cluster <font color='red'> endpoint and role ARN </font> </h2>

# %% [markdown]
# <font color='red'>DO NOT RUN THIS unless the cluster status becomes "Available" </font>

# %%
DWH_ENDPOINT = myClusterProps['Endpoint']['Address']
DWH_ROLE_ARN = myClusterProps['IamRoles'][0]['IamRoleArn']

print("DWH_ENDPOINT :: ", DWH_ENDPOINT)
print("DWH_ROLE_ARN :: ", DWH_ROLE_ARN)

# %% [markdown]
# ## STEP 3: Open an incoming  TCP port to access the cluster ednpoint

# %%
try:
    vpc = ec2.Vpc(id=myClusterProps['VpcId'])
    defaultSg = list(vpc.security_groups.all())[0]
    print(defaultSg)
    defaultSg.authorize_ingress(
        GroupName=defaultSg.group_name,
        CidrIp='0.0.0.0/0',
        IpProtocol='TCP',
        FromPort=int(DWH_PORT),
        ToPort=int(DWH_PORT)
    )
except Exception as e:
    print(e)

# %% [markdown]
# ## STEP 4: Make sure you can connect to the clusterConnect to the cluster

# %%
# %load_ext sql

# %%
conn_string="postgresql://{}:{}@{}:{}/{}".format(DWH_DB_USER, DWH_DB_PASSWORD, DWH_ENDPOINT, DWH_PORT,DWH_DB)
print(conn_string)
# %sql $conn_string

# %% [markdown]
# ### Example query for testing: Which song and artist was played by whom and when

# %%
# %%sql
# select sp.songplay_id, sp.start_time, u.user_id, u.first_name, u.last_name, a.name, s.title
# from songplays sp
#         join users u using(user_id)
#         join songs s using(song_id)
#         join artists a on a.artist_id = sp.artist_id
#         join time using(start_time)
# order by (u.last_name)
# limit 50;
# Out:
#  * postgresql://dwhuser:***@dwhcluster.cbuelyssozhl.us-west-2.redshift.amazonaws.com:5439/dwh
# 50 rows affected.
# [(75, datetime.datetime(2018, 11, 6, 7, 36, 46), '66', 'Kevin', 'Arellano', 'Basshunter', 'Why'),
#  (173, datetime.datetime(2018, 11, 23, 0, 11), '66', 'Kevin', 'Arellano', 'Soziedad Alkoholika', 'Va Bien'),
#  (75, datetime.datetime(2018, 11, 6, 7, 36, 46), '66', 'Kevin', 'Arellano', 'Basshunter feat. DJ Mental Theos Bazzheadz', 'Why'),
#  (1, datetime.datetime(2018, 11, 7, 7, 58, 28), '100', 'Adler', 'Barrera', 'Jagged Edge', "Let's Get Married"),
#  (418, datetime.datetime(2018, 11, 20, 15, 50, 1), '100', 'Adler', 'Barrera', 'Lonnie Gordon', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)'),
#  (1, datetime.datetime(2018, 11, 7, 7, 58, 28), '100', 'Adler', 'Barrera', 'Jagged Edge featuring Run of Run DMC', "Let's Get Married"),
#  (1, datetime.datetime(2018, 11, 7, 7, 58, 28), '100', 'Adler', 'Barrera', 'Jagged Edge Featuring Major Damage', "Let's Get Married"),
#  (311, datetime.datetime(2018, 11, 5, 10, 18, 12), '42', 'Harper', 'Barrett', 'Dwight Yoakam', "You're The One"),
#  (21, datetime.datetime(2018, 11, 9, 0, 12, 27), '42', 'Harper', 'Barrett', 'Shakira', 'Pienso En Ti'),
#  (313, datetime.datetime(2018, 11, 15, 17, 9, 53), '42', 'Harper', 'Barrett', 'La Fuga', 'Baja por diversion (directo 05)'),
#  (36, datetime.datetime(2018, 11, 5, 10, 41, 2), '42', 'Harper', 'Barrett', 'The Cardigans', 'Lovefool'),
#  (21, datetime.datetime(2018, 11, 9, 0, 12, 27), '42', 'Harper', 'Barrett', 'Shakira Featuring Wyclef Jean', 'Pienso En Ti'),
#  (211, datetime.datetime(2018, 11, 15, 19, 1, 55), '42', 'Harper', 'Barrett', 'matchbox twenty', 'Unwell (Album Version)'),
#  (35, datetime.datetime(2018, 11, 20, 11, 1), '42', 'Harper', 'Barrett', 'New Radicals', 'You Get What You Give'),
#  (157, datetime.datetime(2018, 11, 5, 14, 39, 43), '91', 'Jayden', 'Bell', 'Steve Miller Band', 'The Joker'),
#  (73, datetime.datetime(2018, 11, 7, 15, 16, 17), '2', 'Jizelle', 'Benjamin', 'Los Del Rio', 'Macarena'),
#  (29, datetime.datetime(2018, 11, 6, 16, 38, 15), '2', 'Jizelle', 'Benjamin', 'Shakira', 'Pienso En Ti'),
#  (29, datetime.datetime(2018, 11, 6, 16, 38, 15), '2', 'Jizelle', 'Benjamin', 'Shakira Featuring Wyclef Jean', 'Pienso En Ti'),
#  (67, datetime.datetime(2018, 11, 28, 8, 9, 40), '58', 'Emily', 'Benson', 'Kate Voegele', 'One Way Or Another'),
#  (57, datetime.datetime(2018, 11, 23, 17, 29, 9), '58', 'Emily', 'Benson', 'India.Arie', 'Beautiful Flower'),
#  (263, datetime.datetime(2018, 11, 14, 9, 10, 49), '58', 'Emily', 'Benson', 'Dwight Yoakam', "You're The One"),
#  (155, datetime.datetime(2018, 11, 28, 7, 15, 21), '58', 'Emily', 'Benson', 'Counting Crows', 'Mr. Jones'),
#  (129, datetime.datetime(2018, 11, 28, 8, 23, 13), '58', 'Emily', 'Benson', 'Efecto Mariposa', 'Por quererte'),
#  (104, datetime.datetime(2018, 11, 21, 15, 30), '58', 'Emily', 'Benson', 'Ghostland Observatory', 'Stranger Lover'),
#  (192, datetime.datetime(2018, 11, 23, 16, 13, 8), '58', 'Emily', 'Benson', 'Boys Like Girls featuring Taylor Swift', 'Two Is Better Than One'),
#  (192, datetime.datetime(2018, 11, 23, 16, 13, 8), '58', 'Emily', 'Benson', 'Boys Like Girls', 'Two Is Better Than One'),
#  (8, datetime.datetime(2018, 11, 28, 8, 18, 57), '58', 'Emily', 'Benson', 'Luis Miguel', 'Suena ("Some Day" end title song "The Hunchback of Notre Dame")'),
#  (160, datetime.datetime(2018, 11, 28, 7, 11, 30), '58', 'Emily', 'Benson', 'Plus One', 'You (w/o Organ Version)'),
#  (53, datetime.datetime(2018, 11, 26, 15, 33, 56), '72', 'Hayden', 'Brock', 'Foo Fighters', 'Hell'),
#  (338, datetime.datetime(2018, 11, 26, 13, 55, 17), '72', 'Hayden', 'Brock', 'Usher', "Hey Daddy (Daddy's Home)"),
#  (338, datetime.datetime(2018, 11, 26, 13, 55, 17), '72', 'Hayden', 'Brock', 'Usher featuring Jermaine Dupri', "Hey Daddy (Daddy's Home)"),
#  (216, datetime.datetime(2018, 11, 15, 16, 4, 40), '32', 'Lily', 'Burns', 'Natasha Bedingfield', 'These Words'),
#  (60, datetime.datetime(2018, 11, 16, 16, 27, 21), '90', 'Andrea', 'Butler', 'Thousand Foot Krutch', 'The Invitation'),
#  (49, datetime.datetime(2018, 11, 20, 1, 8, 25), '94', 'Noah', 'Chavez', 'Emmy The Great', 'Mia'),
#  (186, datetime.datetime(2018, 11, 8, 14, 27, 8), '81', 'Sienna', 'Colon', 'Metallica', 'Fade To Black'),
#  (98, datetime.datetime(2018, 11, 29, 2, 36, 13), '54', 'Kaleb', 'Cook', 'Kid Cudi', 'Make Her Say'),
#  (98, datetime.datetime(2018, 11, 29, 2, 36, 13), '54', 'Kaleb', 'Cook', 'Kid Cudi / Kanye West / Common', 'Make Her Say'),
#  (466, datetime.datetime(2018, 11, 2, 17, 31, 45), '10', 'Sylvie', 'Cruz', 'Lonnie Gordon', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)'),
#  (329, datetime.datetime(2018, 11, 30, 6, 54, 42), '49', 'Chloe', 'Cuevas', 'Tempa T', 'Next Hype'),
#  (482, datetime.datetime(2018, 11, 29, 18, 21, 24), '49', 'Chloe', 'Cuevas', 'Beirut', 'My Night With the Prostitute From Marseille'),
#  (233, datetime.datetime(2018, 11, 30, 5, 57, 11), '49', 'Chloe', 'Cuevas', 'B.o.B', "Nothin' On You [feat. Bruno Mars] (Album Version)"),
#  (250, datetime.datetime(2018, 11, 30, 12, 39, 36), '49', 'Chloe', 'Cuevas', 'Ron Carter', "I CAN'T GET STARTED"),
#  (97, datetime.datetime(2018, 11, 28, 17, 39, 27), '49', 'Chloe', 'Cuevas', 'Arctic Monkeys', 'From The Ritz To The Rubble'),
#  (386, datetime.datetime(2018, 11, 29, 15, 54, 12), '49', 'Chloe', 'Cuevas', 'Plies', 'I Am The Club (Explicit Album Version)'),
#  (193, datetime.datetime(2018, 11, 24, 15, 47, 42), '49', 'Chloe', 'Cuevas', 'Arctic Monkeys', 'Fake Tales Of San Francisco'),
#  (402, datetime.datetime(2018, 11, 30, 17, 25, 36), '49', 'Chloe', 'Cuevas', 'Lonnie Gordon', 'Catch You Baby (Steve Pitron & Max Sanna Radio Edit)'),
#  (177, datetime.datetime(2018, 11, 30, 7, 47, 5), '49', 'Chloe', 'Cuevas', 'Donovan', 'Starfish-On-The-Toast (2008 Digital Remaster)'),
#  (274, datetime.datetime(2018, 11, 9, 20, 13, 58), '49', 'Chloe', 'Cuevas', 'Ron Carter', "I CAN'T GET STARTED"),
#  (297, datetime.datetime(2018, 11, 29, 18, 5, 39), '49', 'Chloe', 'Cuevas', 'Duncan Dhu', 'No Puedo Evitar (Pensar En Ti)'),
#  (474, datetime.datetime(2018, 11, 29, 16, 58, 1), '49', 'Chloe', 'Cuevas', 'Lupe Fiasco', 'Fighters (feat. Matthew Santos) (Amended Album Version)')]

# %% [markdown]
# ## STEP 5: Clean up your resources

# %% [markdown]
# <b><font color='red'>DO NOT RUN THIS UNLESS YOU ARE SURE <br/>

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
redshift.delete_cluster( ClusterIdentifier=DWH_CLUSTER_IDENTIFIER,  SkipFinalClusterSnapshot=True)
#### CAREFUL!!

# %% [markdown]
# - run this block several times until the cluster really deleted

# %%
myClusterProps = redshift.describe_clusters(ClusterIdentifier=DWH_CLUSTER_IDENTIFIER)['Clusters'][0]
prettyRedshiftProps(myClusterProps)

# %%
#### CAREFUL!!
#-- Uncomment & run to delete the created resources
iam.detach_role_policy(RoleName=DWH_IAM_ROLE_NAME, PolicyArn="arn:aws:iam::aws:policy/AmazonS3ReadOnlyAccess")
iam.delete_role(RoleName=DWH_IAM_ROLE_NAME)
#### CAREFUL!!
